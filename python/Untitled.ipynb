# %%
import raster_drone as rd
import matplotlib.pyplot as plt
import numpy as np

# %%
vals = np.array(rd.process_image("teacup.jpg", 1000, 0.30))
# Out:
# Image loaded successfully with dimensions: 1000x1080
# Extracted 323997 initial coordinates.
# Sampled down to 1000 coordinates using a grid.

# %%
plt.imshow(vals)

# %%
len(vals[0])
# Out:
# 1080

# %%
type(vals)
# Out:
# numpy.ndarray
